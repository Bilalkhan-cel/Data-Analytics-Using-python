# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilalkhan-cel/Data-Analytics-Using-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print("Hello")
# Out:
# Hello

# %%
# !git clone https://github.com/Bilalkhan-cel/Data-Analytics-Using-python.git
# Out:
# Cloning into 'Data-Analytics-Using-python'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 19.79 KiB | 613.00 KiB/s, done.

# %%
df=pd.read_csv("/content/Data-Analytics-Using-python/FATIMA-prices-2022-11-02.csv")

# %%
df.head()
# Out:
#           date   open   high    low  close     volume  change
# 0  02-Nov-2022  36.00  36.20  35.90  36.03     14,504    0.03
# 1  01-Nov-2022  35.45  36.09  35.45  36.00     17,664    0.55
# 2  31-Oct-2022  35.20  35.48  35.20  35.45     30,029    0.27
# 3  28-Oct-2022  35.80  36.00  35.02  35.18     39,927   -0.32
# 4  27-Oct-2022  36.35  36.79  35.25  35.50  1,024,517   -1.29

# %%
df.describe()
# Out:
#               open         high          low        close       change
# count  1188.000000  1188.000000  1188.000000  1188.000000  1188.000000
# mean     30.728392    31.191221    30.361380    30.799857     0.016322
# std       4.358492     4.450115     4.294183     4.378289     0.530706
# min      19.270000    21.020000    19.260000    20.820000    -2.180000
# 25%      27.600000    27.990000    27.250000    27.672500    -0.270000
# 50%      29.505000    30.000000    29.130000    29.605000    -0.010000
# 75%      34.517500    35.100000    34.250000    34.752500     0.290000
# max      42.450000    44.500000    41.850000    42.180000     2.320000

# %%
! git add.
# Out:
# git: 'add.' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add

# %%
# !git add.
# Out:
# git: 'add.' is not a git command. See 'git --help'.
#
# The most similar command is
# 	add

# %%
# !git commit -m "hello"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
